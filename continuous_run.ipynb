# %%
# %run music_rank-v2-only_result
# Out:
# ranking No:6   artist:Selena Gomez  music:Same Old Love
#
# http://twitter.com/selenagomez
#
# ranking No:7   artist:Young Thug  music:Check
#
# http://twitter.com/youngthug
#
# ranking No:8   artist:Wale  music:The Matrimony
#
# http://twitter.com/Wale
#
# ranking No:9   artist:One Direction  music:Walking In The Wind
#
# http://twitter.com/onedirection
#
# ranking No:10   artist:Big Sean  music:Win Some, Lose Some (feat. Jhené Aiko)
#
# http://twitter.com/BigSean

# %%
from win32api import *
from time import *

i = 1
#print("The job has been executed", i, "times till now.")
while 1:
    # %run music_rank-v2-only_result2   
    print("-------------The job has been executed", i, "times till now.-----------------------",'\n')
    i += 1
    sleep(30)
# Out:
# ranking No:6   artist:Justin Bieber  music:Sorry
#
# -------------The job has been executed 1 times till now.-----------------------
#
# ranking No:6   artist:Justin Bieber  music:Sorry
